# %%
from notebook_util_mine import *
# %matplotlib inline

# %%
from minee.data.mix_gaussian import MixedGaussian

# %%
## Data

np.random.seed(0)
sample_size = 200
rho1 = 0.9
data = MixedGaussian(sample_size=sample_size,rho1=rho1).data
data_t = torch.Tensor(data)

# %%
X = data[:,[0]]
Y = data[:,[1]]

# %%
plt.scatter(X,Y)

# %%
X_ref = resample(X,batch_size=sample_size)
Y_ref = resample(Y,batch_size=sample_size)

# %%
plt.scatter(X,Y,label="data",marker="+",color="steelblue")
plt.scatter(X_ref,Y_ref,label="ref",marker="_",color="darkorange")
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Plot of all data samples and reference samples')
plt.legend()

# %%
batch_size = int(sample_size*1)
lr = 1e-3
ma_rate = 0.1
fname = 'mix_gaussian_mine_full_batch_ma.pt'

# %%
from minee.model.mine import Mine

# %%
mine = Mine(
            lr=lr, 
            batch_size=batch_size,
            ma_rate=ma_rate,
            hidden_size=300,
            snapshot=list(range(200, int(1e4), 200)),
            iter_num=int(1e4),
            log=True,
            verbose=False
        )

# %%
test_data = MixedGaussian(sample_size=sample_size,rho1=rho1).data
test_data_t = torch.Tensor(test_data)
test_X = test_data[:,[0]]
test_Y = test_data[:,[1]]
plt.scatter(test_X,test_Y)

# %%
mine.predict(X,Y,test_X,test_Y)
# Out:
# 0.41471338272094727
